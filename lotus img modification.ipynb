# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from PIL import Image

# %%
lotus= Image.open(r'C:\Users\Hp\Desktop\lotus.jpg')
lotus
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x224>

# %%
type(lotus)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
plt.imshow(lotus)

# %%
plt.show(lotus)

# %%
lotus_arr = np.asarray(lotus)
lotus_arr
# Out:
# array([[[ 17,  21,  46],
#         [ 17,  21,  46],
#         [ 18,  23,  45],
#         ...,
#         [112, 112,  48],
#         [112, 112,  48],
#         [114, 114,  50]],
#
#        [[ 13,  21,  40],
#         [ 14,  22,  41],
#         [ 14,  23,  40],
#         ...,
#         [110, 110,  46],
#         [110, 110,  46],
#         [111, 111,  47]],
#
#        [[ 13,  29,  44],
#         [ 12,  28,  43],
#         [ 12,  28,  43],
#         ...,
#         [107, 107,  43],
#         [107, 107,  43],
#         [108, 108,  44]],
#
#        ...,
#
#        [[ 98, 130,  19],
#         [ 96, 128,  17],
#         [ 97, 129,  18],
#         ...,
#         [ 86,  80,  46],
#         [ 86,  80,  46],
#         [ 90,  87,  46]],
#
#        [[108, 141,  24],
#         [104, 137,  20],
#         [101, 134,  17],
#         ...,
#         [ 83,  77,  43],
#         [ 83,  77,  43],
#         [ 90,  86,  49]],
#
#        [[112, 147,  21],
#         [107, 142,  16],
#         [103, 138,  12],
# ...

# %%
lotus_arr.shape
# Out:
# (224, 225, 3)

# %%
flower= lotus.copy()
flower
# Out:
# <PIL.Image.Image image mode=RGB size=225x224>

# %%
lotus == flower
# Out:
# False

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.imshow(lotus_arr)
plt.show()

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(lotus_arr[:,:,0])

# %%
plt.imshow(lotus_arr[:,:,0], cmap='grey')
plt.show()

# %%
plt.imshow(lotus_arr,cmap='Blues')
plt.show()

# %%
plt.axis('off')
# Out:
# (-0.5, 224.5, 223.5, -0.5)

# %%
plt.imshow(lotus_arr)
plt.show()

# %%
plt.show()

# %%
lotus_arr[:,:,2]
# Out:
# array([[46, 46, 45, ..., 48, 48, 50],
#        [40, 41, 40, ..., 46, 46, 47],
#        [44, 43, 43, ..., 43, 43, 44],
#        ...,
#        [19, 17, 18, ..., 46, 46, 46],
#        [24, 20, 17, ..., 43, 43, 49],
#        [21, 16, 12, ..., 41, 39, 46]], dtype=uint8)

# %%
lotus_arr[:,:,2] =0
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lotus_arr[:,:,2] =0
#       2 plt.show
#
# ValueError: assignment destination is read-only
